# %% [markdown]
# <a href="https://colab.research.google.com/github/cesarmontenegrosilva/consumo_bandeiras_tarifarias/blob/main/Notebooks/Consumo_Energia_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import xlrd

# %%
xls = '/content/2004_2022_dados_.xlsx'

# %%
dados = pd.read_excel(xls, '2004_2022')

# %%
import matplotlib.pyplot as plt

# %%
#Plooting the data with plotly.express
import plotly.express as px

fig = px.line(dados, x='Mes', y=['Cons.ResidencialTotal', 'Cons.IndustrialTotal', 'Cons.ComercialTotal', 'Cons.Total.Outros (MWh)'])
#editing the plot and the plotly.express library
fig.update_layout(title='Consumo de Energia (MWh)',
                    xaxis_title='Date',
                    yaxis_title='MWh',
                    yaxis_autorange=True)
#adding mean and median horizontal lines to the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Plooting the data with plotly.express
import plotly.express as px

fig = px.line(dados, x='Mes', y=['CativoInd', 'LivreIndustrial'])
#editing the plot and the plotly.express library
fig.update_layout(title='Consumo de Energia (MWh)',
                    xaxis_title='Date',
                    yaxis_title='MWh',
                    yaxis_autorange=True)
#adding mean and median horizontal lines to the plot
#fig.add_hline(y=media, line_width=3, line_dash="dot", line_color="red")
#fig.add_hline(y=mediana, line_width=3, line_dash="dash", line_color="green")
fig.add_hline(y=dados['CativoInd'].median(),line_width=3, line_dash="dot", line_color="blue")
fig.add_hline(y=dados['LivreIndustrial'].median(), line_width=3, line_dash="dash", line_color="red")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Plooting the data with plotly.express
import plotly.express as px

fig = px.line(dados, x='Mes', y=['CativoInd', 'LivreIndustrial'])
#editing the plot and the plotly.express library
fig.update_layout(title='Consumo de Energia (MWh)',
                    xaxis_title='Date',
                    yaxis_title='MWh',
                    yaxis_autorange=True)
#adding mean and median horizontal lines to the plot
#fig.add_hline(y=media, line_width=3, line_dash="dot", line_color="red")
#fig.add_hline(y=mediana, line_width=3, line_dash="dash", line_color="green")
fig.add_hline(y=dados['CativoInd'].median(),line_width=3, line_dash="dot", line_color="blue")
fig.add_hline(y=dados['LivreIndustrial'].median(), line_width=3, line_dash="dash", line_color="red")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Plooting the data with plotly.express
import plotly.express as px

fig = px.line(dados, x='Mes', y=['CativoCom', 'LivreComercial'])
#editing the plot and the plotly.express library
fig.update_layout(title='Consumo de Energia (MWh)',
                    xaxis_title='Date',
                    yaxis_title='MWh',
                    yaxis_autorange=True)
#adding mean and median horizontal lines to the plot
#fig.add_hline(y=media, line_width=3, line_dash="dot", line_color="red")
#fig.add_hline(y=mediana, line_width=3, line_dash="dash", line_color="green")
fig.add_hline(y=dados['CativoCom'].median(),line_width=3, line_dash="dot", line_color="blue")
fig.add_hline(y=dados['LivreComercial'].median(), line_width=3, line_dash="dash", line_color="red")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dados.describe().round(2)
# Out:
#        IndiceMes    Hmes  ResidencialN  ResidencialNE  ResidencialSE  \
# count     221.00  221.00        221.00         221.00         221.00
# mean      111.00  730.32     609715.87     1856878.73     4972188.71
# std        63.94   19.70     195671.62      531255.69      787982.75
# min         1.00  673.00     320237.37      962934.27     3433442.50
# 25%        56.00  720.00     408304.00     1332020.00     4292183.00
# 50%       111.00  744.00     604096.00     1927736.00     5108683.00
# 75%       166.00  744.00     795848.71     2298488.62     5536523.80
# max       221.00  744.00     991349.19     2828625.11     6643389.63
#
#        ResidencialS  ResidencialCO  Cons.ResidencialTotal  \
# count        221.00         221.00                 221.00
# mean     1574119.84      801506.97             9814410.12
# std       318082.27      215093.50             2000996.50
# min      1056850.13      466358.82             6291091.44
# ...

# %%
import seaborn as sns

# %%
ax = sns.boxplot(data = dados[['Cons.ResidencialTotal', 'Cons.IndustrialTotal', 'Cons.ComercialTotal', 'Cons.Total.Outros (MWh)']])
ax.figure.set_size_inches(12,6)
ax.set_title('Consumo Total', fontsize = 20)
ax.set_xlabel('MWh', fontsize = 16)
ax

# %%
ax = sns.distplot(dados['Cons.IndustrialTotal'])
ax.figure.set_size_inches(12,6)
ax.set_title('Distribuição de Frequências', fontsize = 20)
ax.set_xlabel('Consumo IndTotal (MWh)', fontsize = 16)
ax
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
ax = sns.distplot(dados['Cons.ResidencialTotal'])
ax.figure.set_size_inches(12,6)
ax.set_title('Distribuição de Frequências', fontsize = 20)
ax.set_xlabel('Consumo ResTotal (MWh)', fontsize = 16)
ax
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
ax = sns.distplot(dados['Cons.ComercialTotal'])
ax.figure.set_size_inches(12,6)
ax.set_title('Distribuição de Frequências', fontsize = 20)
ax.set_xlabel('Consumo ComTotal (MWh)', fontsize = 16)
ax
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
import numpy as np

# %%
dados['log_Cons.ComercialTotal'] = np.log(dados['Cons.ComercialTotal'])
dados['log_Cons.ResidencialTotal'] = np.log(dados['Cons.ResidencialTotal'])
dados['log_Cons.IndustrialTotal'] = np.log(dados['Cons.IndustrialTotal'])

# %%
dados.head()
# Out:
#          Mes  IndiceMes  Hmes  ResidencialN  ResidencialNE  ResidencialSE  \
# 0 2004-01-01          1   744     348584.78     1098663.59     3694385.61
# 1 2004-02-01          2   697     323402.68     1000221.33     3511541.26
# 2 2004-03-01          3   744     320237.37     1049437.16     3629455.43
# 3 2004-04-01          4   720     339774.86     1097250.59     3733863.11
# 4 2004-05-01          5   744     332154.91     1033006.84     3537268.72
#
#    ResidencialS  ResidencialCO  Cons.ResidencialTotal  \
# 0    1132506.01      506540.49             6780680.48
# 1    1121970.48      472102.53             6429238.28
# 2    1108027.32      493180.88             6600338.16
# 3    1132047.07      506070.92             6809006.55
# 4    1082102.57      492808.31             6477341.35
#
#    Cons.ResidencialTotal (GWh)  ...  Dummy2014  Dummy2015  Dummy2016  \
# 0                   6780.68048  ...          0          0          0
# ...

# %%
ax = sns.distplot(dados['log_Cons.IndustrialTotal'])
ax.figure.set_size_inches(12, 6)
ax.set_title('Distribuição de Frequências', fontsize=20)
ax.set_xlabel('log_Cons.IndustrialTotal', fontsize=16)
ax
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
dados.columns
# Out:
# Index(['Mes', 'IndiceMes', 'Hmes', 'ResidencialN', 'ResidencialNE',
#        'ResidencialSE', 'ResidencialS', 'ResidencialCO',
#        'Cons.ResidencialTotal', 'Cons.ResidencialTotal (GWh)', 'IndustrialN',
#        'IndustrialNE', 'IndustrialSE', 'IndustrialS', 'IndustrialCO',
#        'Cons.IndustrialTotal', 'Cons.IndustrialTotal(GWh)', 'ComercialN',
#        'ComercialNE', 'ComercialSE', 'ComercialS', 'ComercialCO',
#        'Cons.ComercialTotal', 'Cons.ComercialTotal (GWh)', 'OutrosN',
#        'OutrosNE', 'OutrosSE', 'OutrosS', 'OutrosCO',
#        'Cons.Total.Outros (MWh)', 'Cons.Total.Outros (GWh)', 'CativoRes',
#        'CativoInd', 'CativoCom', 'CativoOutros', 'Cons.Total.Cativo (MWh)',
#        'Cons.Total.Cativo (MWh).1', 'Cons.Total.Cativo (GWh)',
#        'CativoResidencial(730)', 'CativoIndustrial(730)',
#        'CativoComercial(730)', 'LivreIndustrial', 'LivreComercial',
#        'ConsCatTotal(MWh)', 'ConsLivreTotal(MWh)', 'BandeiraAmarela',
# ...

# %%
dados1 = dados[36:]
dados1
# Out:
#            Mes  IndiceMes  Hmes  ResidencialN  ResidencialNE  ResidencialSE  \
# 36  2007-01-01         37   744     377018.00     1259580.00     4183534.00
# 37  2007-02-01         38   673     364503.00     1208193.00     4000465.00
# 38  2007-03-01         39   744     352883.00     1194430.00     4219240.00
# 39  2007-04-01         40   720     371967.00     1244458.00     4223592.00
# 40  2007-05-01         41   744     371605.00     1218867.00     4104316.00
# ..         ...        ...   ...           ...            ...            ...
# 216 2022-01-01        217   744     880314.16     2687346.03     5997245.54
# 217 2022-02-01        218   673     831197.15     2575407.84     6140818.14
# 218 2022-03-01        219   744     888334.35     2805033.08     6643389.63
# 219 2022-04-01        220   720     862009.73     2628483.30     6267094.51
# 220 2022-05-01        221   744     899685.43     2676005.50     5713017.71
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y = dados1['Cons.Total.Cativo (MWh)']

# %%
X = dados1[['BandeiraAmarela', 'BandeiraVermelhaP1', 'BandeiraVermelhaP2', 'BandeiraEscassHidrica']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2811)

# %%
import statsmodels.api as sm

# %%
X_train_com_constante = sm.add_constant(X_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning:
#
# In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only

# %%
X_train_com_constante
# Out:
#      const  BandeiraAmarela  BandeiraVermelhaP1  BandeiraVermelhaP2  \
# 205    1.0                1                   0                   0
# 59     1.0                0                   0                   0
# 171    1.0                0                   0                   0
# 130    1.0                0                   1                   0
# 67     1.0                0                   0                   0
# ..     ...              ...                 ...                 ...
# 64     1.0                0                   0                   0
# 109    1.0                0                   0                   0
# 104    1.0                0                   0                   0
# 121    1.0                0                   1                   0
# 120    1.0                1                   0                   0
#
#      BandeiraEscassHidrica
# 205                      0
# 59                       0
# 171                      0
# 130                      0
# ...

# %%
modelo_statsmodels = sm.OLS(y_train, X_train_com_constante, hasconst = True).fit()

# %%
print(modelo_statsmodels.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Cons.Total.Cativo (MWh)   R-squared:                       0.298
# Model:                                 OLS   Adj. R-squared:                  0.279
# Method:                      Least Squares   F-statistic:                     15.21
# Date:                     Fri, 11 Nov 2022   Prob (F-statistic):           2.21e-10
# Time:                             11:26:07   Log-Likelihood:                -2301.8
# No. Observations:                      148   AIC:                             4614.
# Df Residuals:                          143   BIC:                             4629.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...
